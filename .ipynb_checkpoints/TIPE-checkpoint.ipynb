# %% [markdown]
# # TIPE

# %% [markdown]
# ## Requirements and Settings

# %%
import os
import uuid
import cv2
from PIL import Image, ImageDraw

# %% [markdown]
# ## Dataset load

# %%
import tensorflow as tf
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
images = tf.data.Dataset.list_files('data\\extracted\\*.jpg', shuffle=False)

# %%
def load_image(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

def load_im_mask(x):
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_png(byte_img)
    return img

# %%
images = images.map(load_image)

# %%
# images.as_numpy_iterator().next()

# %%
image_generator = images.batch(4).as_numpy_iterator()

# %%
plot_images = image_generator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, image in enumerate(plot_images):
    ax[idx].imshow(image)
plt.show()

# %% [markdown]
# ## Data Split

# %%
# Here split images into three folders: train / test / val
# Need enough amount of images
# 70% for train, 15% for each test and val

# %%
for folder in  ['train', 'test', 'val']:
    for file in os.listdir(os.path.join('data', 'images', folder)):
        filename = file.split('.')[0]+'.png'
        existing_filepath = os.path.join('data', 'masks', filename)
        if os.path.exists(existing_filepath):
            new_filepath = os.path.join('data','images', folder + "_masks", filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# ## Augmentation

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([alb.CropNonEmptyMaskIfExists(width=750, height=421), alb.HorizontalFlip(p=0.5), alb.RandomBrightnessContrast(p=0.2), alb.RandomGamma(p=0.2)])

# %%
image = plt.imread(os.path.join('data', 'images', "train",'a0b9f304-d6ed-11ed-bd4d-b808cfebfb26.jpg'))
mask = plt.imread(os.path.join('data', 'images', "train_masks", 'a0b9f304-d6ed-11ed-bd4d-b808cfebfb26.png'))

# %%
plt.imshow(image)
plt.imshow(mask, cmap='jet', alpha=0.5)

# %%
transformed = augmentor(image=image, mask=mask)
newim=cv2.resize(transformed['image'], dsize=(1564,880))
newmask=cv2.resize(transformed['mask'], dsize=(1564,880))
plt.imshow(newim)
plt.imshow(newmask.astype(int), cmap='jet', alpha=0.5)
# plt.imsave('test.png', newmask, cmap='gray')
Image.fromarray(mask.astype("b1")).save("test.png")

# %%
# for file in os.listdir(os.path.join('data', 'images')):
#     filename = file.split('.')[0]
#     image = plt.imread(os.path.join('data', 'images', file))
#     mask = plt.imread(os.path.join('data', 'masks', filename+'.png'))
#     for i in range(500):
#         transformed = augmentor(image=image, mask=mask)
#         plt.imsave(os.path.join('data', 'images', filename+ '.' + str(i) +'.jpg'), transformed['image'])
#         plt.imsave(os.path.join('data', 'masks', filename+'.' + str(i) +'.png'), transformed['mask'], cmap='gray')

for folder in  ['train', 'test', 'val']:        
    for file in os.listdir(os.path.join('data', 'images', folder)):
        filename = file.split('.')[0]
        image = plt.imread(os.path.join("data", "images", folder, file))
        mask = plt.imread(os.path.join('data', 'images', folder+"_masks", filename+".png"))
        for i in range(10):
            transformed = augmentor(image=image, mask=mask)
            plt.imsave(os.path.join('data', 'images', folder ,filename+ '.' + str(i) +'.jpg'), transformed['image'])
            Image.fromarray(transformed['mask'].astype("b1")).save(os.path.join('data', 'images', folder+"_masks", filename+'.' + str(i) +'.png'))

# %% [markdown]
# ## Datasets

# %%
train_images = tf.data.Dataset.list_files('data\\images\\train\\*.jpg', shuffle=False)
train_images = train_images.map(load_image)
train_images = train_images.map(lambda x: tf.image.resize(x, (104,184)))
train_images = train_images.map(lambda x: x/255)

# %%
val_images = tf.data.Dataset.list_files('data\\images\\val\\*.jpg', shuffle=False)
val_images = val_images.map(load_image)
val_images = val_images.map(lambda x: tf.image.resize(x, (104,184)))
val_images = val_images.map(lambda x: x/255)

# %%
test_images = tf.data.Dataset.list_files('data\\images\\test\\*.jpg', shuffle=False)
test_images = test_images.map(load_image)
test_images = test_images.map(lambda x: tf.image.resize(x, (104,184)))
test_images = test_images.map(lambda x: x/255)

# %%
# train_images.as_numpy_iterator().next()

# %%
def load_masks (img) :
    ret= np.zeros((img.shape[0], img.shape[1]))
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if img[i,j,0] == 1:
                ret[i,j] = 1
    return ret

# %%
train_masks = tf.data.Dataset.list_files('data\\images\\train_masks\\*.png', shuffle=False)
train_masks = train_masks.map(load_im_mask)
# train_masks = train_masks.map(lambda x: tf.image.rgb_to_grayscale(x))
train_masks = train_masks.map(lambda x: tf.image.resize(x, (104,184)))
train_masks = train_masks.map(lambda x: x//255)

# %%
val_masks = tf.data.Dataset.list_files('data\\images\\val_masks\\*.png', shuffle=False)
val_masks = val_masks.map(load_im_mask)
# train_masks = train_masks.map(lambda x: tf.image.rgb_to_grayscale(x))
val_masks = val_masks.map(lambda x: tf.image.resize(x, (104,184)))
val_masks = val_masks.map(lambda x: x//255)

# %%
test_masks = tf.data.Dataset.list_files('data\\images\\test_masks\\*.png', shuffle=False)
test_masks = test_masks.map(load_im_mask)
# train_masks = train_masks.map(lambda x: tf.image.rgb_to_grayscale(x))
test_masks = test_masks.map(lambda x: tf.image.resize(x, (104,184)))
test_masks = test_masks.map(lambda x: x//255)

# %%
# do the same for test and validations
train_masks.as_numpy_iterator().next().shape
# Out:
# (104, 184, 1)

# %%
len(train_images),len(train_masks)
# Out:
# (539, 539)

# %%
train = tf.data.Dataset.zip((train_images, train_masks))
train = train.shuffle(3*len(train_images))
train = train.batch(8)
train = train.prefetch(4)

# %%
val = tf.data.Dataset.zip((val_images, val_masks))
val = val.shuffle(3*len(val_images))
val = val.batch(8)
val = val.prefetch(4)

# %%
test = tf.data.Dataset.zip((test_images, test_masks))
test = test.shuffle(3*len(test_images))
test = test.batch(8)
test = test.prefetch(4)

# %%
train
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 104, 184, None), dtype=tf.float32, name=None), TensorSpec(shape=(None, 104, 184, None), dtype=tf.float32, name=None))>

# %%
# do the same for test and validations

# %%
train.as_numpy_iterator().next()[0].shape
# Out:
# (8, 104, 184, 3)

# %%
data_samples = train.as_numpy_iterator()

# %%
res = data_samples.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4):
    image=res[0][idx]
    mask=res[1][idx]
    ax[idx].imshow(image)
    ax[idx].imshow(mask, cmap='jet', alpha=0.5)
plt.show()

# %% [markdown]
# ## Deep Learning

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv3D, Dense, GlobalMaxPooling2D, GlobalMaxPooling3D, UpSampling2D, MaxPool2D, MaxPooling2D, Dropout, Concatenate

# %%
def build_model():
    input_shape = (104, 184, 3)

    # Define the input layer
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)

    # Decoder
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    up5 = UpSampling2D((2, 2))(drop4)
    up5 = Conv2D(128, (3, 3), activation='relu', padding='same')(up5)
    concat5 = Concatenate()([conv3, up5])

    conv5 = Conv2D(128, (3, 3), activation='relu', padding='same')(concat5)
    conv5 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv5)
    up6 = UpSampling2D((2, 2))(conv5)
    up6 = Conv2D(64, (3, 3), activation='relu', padding='same')(up6)
    concat6 = Concatenate()([conv2, up6])

    conv6 = Conv2D(64, (3, 3), activation='relu', padding='same')(concat6)
    conv6 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv6)
    up7 = UpSampling2D((2, 2))(conv6)
    up7 = Conv2D(32, (3, 3), activation='relu', padding='same')(up7)
    concat7 = Concatenate()([conv1, up7])

    conv7 = Conv2D(32, (3, 3), activation='relu', padding='same')(concat7)
    conv7 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv7)

    # Output layer
    output = Conv2D(1, (1, 1), activation='sigmoid')(conv7)
    
    # Create the model
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
roadmodel = build_model()

# %%
roadmodel.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 104, 184, 3  0           []
#                                 )]
#
#  conv2d_18 (Conv2D)             (None, 104, 184, 32  896         ['input_2[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 104, 184, 32  9248        ['conv2d_18[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 92, 32)  0           ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 52, 92, 64)   18496       ['max_pooling2d_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 52, 92, 64)   36928       ['conv2d_20[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 26, 46, 64)  0           ['conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 26, 46, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 26, 46, 128)  147584      ['conv2d_22[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 23, 128)  0          ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 13, 23, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 13, 23, 256)  590080      ['conv2d_24[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 23, 256)  0           ['conv2d_25[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 26, 46, 256)  0          ['dropout_1[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 26, 46, 128)  295040      ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 26, 46, 256)  0           ['conv2d_23[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 26, 46, 128)  295040      ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 26, 46, 128)  147584      ['conv2d_27[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 52, 92, 128)  0          ['conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 52, 92, 64)   73792       ['up_sampling2d_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 52, 92, 128)  0           ['conv2d_21[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 52, 92, 64)   73792       ['concatenate_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 52, 92, 64)   36928       ['conv2d_30[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 104, 184, 64  0          ['conv2d_31[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 104, 184, 32  18464       ['up_sampling2d_5[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 104, 184, 64  0           ['conv2d_19[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 104, 184, 32  18464       ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 104, 184, 32  9248        ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 104, 184, 1)  33          ['conv2d_34[0][0]']
#
# ==================================================================================================
# Total params: 2,140,641
# Trainable params: 2,140,641
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X, Y = train.as_numpy_iterator().next()

# %%
masks = roadmodel.predict(X)
# Out:
# 1/1 [==============================] - 0s 198ms/step

# %% [markdown]
# ## Losses and Optimizers

# %%
from tensorflow.keras.optimizers.legacy import Adam

# %%
batches_per_epoch = len(train)
lr_decay = (1./0.75 -1)/batches_per_epoch

# %%
optimizer = Adam(learning_rate=0.0001, decay=lr_decay)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy()

# %%
loss_fn(Y, masks).numpy()
# Out:
# 0.68518406

# %%
plt.figure(0)
plt.imshow(X[1])
plt.imshow((masks[1]), cmap="jet", alpha=0.5)
plt.show()

# %% [markdown]
# ## Training

# %%
roadmodel.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = roadmodel.fit(train, epochs=40, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/40
# 68/68 [==============================] - 67s 970ms/step - loss: 0.3527 - accuracy: 0.8881 - val_loss: 0.1901 - val_accuracy: 0.8829
# Epoch 2/40
# 68/68 [==============================] - 66s 974ms/step - loss: 0.1658 - accuracy: 0.8982 - val_loss: 0.1813 - val_accuracy: 0.9302
# Epoch 3/40
# 68/68 [==============================] - 66s 969ms/step - loss: 0.1417 - accuracy: 0.9396 - val_loss: 0.1422 - val_accuracy: 0.9432
# Epoch 4/40
# 10/68 [===>..........................] - ETA: 53s - loss: 0.1266 - accuracy: 0.9465

# %%
hist.history
# Out:
# {'loss': [0.3989757001399994,
#   0.17121586203575134,
#   0.1333291083574295,
#   0.11819174885749817,
#   0.06000509858131409,
#   0.03556743264198303,
#   0.030550271272659302,
#   0.027272185310721397,
#   0.024179456755518913,
#   0.022041887044906616],
#  'accuracy': [0.8415904641151428,
#   0.8415906429290771,
#   0.9067043662071228,
#   0.9835224747657776,
#   0.98215252161026,
#   0.9865884780883789,
#   0.9880393147468567,
#   0.9892154335975647,
#   0.9902640581130981,
#   0.9913981556892395]}

# %%
plt.figure(0)
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['accuracy'], color='orange', label='accuracy')
plt.legend()
plt.show()
plt.figure(1)
plt.plot(hist.history['val_loss'], color="teal", label="val_loss")
plt.plot(hist.history['val_accuracy'], color="orange", label="val_accuracy")

# %%
test_sample = test.as_numpy_iterator().next() #replace with test instead of train
# image = plt.imread(os.path.join('data', 'images', '1d6081ab-b9c3-11ed-a745-dc41a9ef7148.jpg'))
# image = tf.image.resize(image, (104,184))

# %%
yhat = roadmodel.predict(test_sample[0])
# Out:
# 1/1 [==============================] - 0s 189ms/step

# %%
yhat.shape
# Out:
# (8, 104, 184, 1)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(40,20))
for idx in range(4):
    image=test_sample[0][idx]
    mask=yhat[idx]
    ax[idx].imshow(image)
    ax[idx].imshow(np.round(mask), cmap='jet', alpha=0.5)
plt.show()

# %%
# plt.imsave("test_mask.png", np.round(yhat[3]), cmap="gray")
# plt.imsave("test_image.png", test_sample[0][3])
plt.imsave("test_mask.png",np.resize(np.round(yhat[3]).astype(int), yhat[3].shape[:2]), cmap="gray")

# %%
type(yhat[0])
# Out:
# numpy.ndarray

# %%
# roadmodel.save('test.h5')

# %%
load_model = tf.keras.models.load_model('test.h5')

# %%
# image=plt.imread(os.path.join('data', 'images', '1d6081ab-b9c3-11ed-a745-dc41a9ef7148.152.jpg'))
image=plt.imread(os.path.join('sample', 'telechargement9.jpg'))
resized=cv2.resize(image, (184,104))
test=load_model.predict(np.expand_dims(resized/255,0))
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
plt.imshow(image)
mask=cv2.resize(np.round(test[0]),image.shape[1::-1])
plt.imshow(mask,cmap='jet',alpha=0.5)

# %%
plt.imsave("test_image.png", image)
plt.imsave("test_mask.png",mask, cmap="gray")

# %%
load_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 104, 184, 3  0           []
#                                 )]
#
#  conv2d_141 (Conv2D)            (None, 104, 184, 32  896         ['input_12[0][0]']
#                                 )
#
#  conv2d_142 (Conv2D)            (None, 104, 184, 32  9248        ['conv2d_141[0][0]']
#                                 )
#
#  max_pooling2d_33 (MaxPooling2D  (None, 52, 92, 32)  0           ['conv2d_142[0][0]']
#  )
#
#  conv2d_143 (Conv2D)            (None, 52, 92, 64)   18496       ['max_pooling2d_33[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 52, 92, 64)   36928       ['conv2d_143[0][0]']
#
#  max_pooling2d_34 (MaxPooling2D  (None, 26, 46, 64)  0           ['conv2d_144[0][0]']
#  )
#
#  conv2d_145 (Conv2D)            (None, 26, 46, 128)  73856       ['max_pooling2d_34[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 26, 46, 128)  147584      ['conv2d_145[0][0]']
#
#  max_pooling2d_35 (MaxPooling2D  (None, 13, 23, 128)  0          ['conv2d_146[0][0]']
#  )
#
#  conv2d_147 (Conv2D)            (None, 13, 23, 256)  295168      ['max_pooling2d_35[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 13, 23, 256)  590080      ['conv2d_147[0][0]']
#
#  dropout_11 (Dropout)           (None, 13, 23, 256)  0           ['conv2d_148[0][0]']
#
#  up_sampling2d_21 (UpSampling2D  (None, 26, 46, 256)  0          ['dropout_11[0][0]']
#  )
#
#  conv2d_149 (Conv2D)            (None, 26, 46, 128)  295040      ['up_sampling2d_21[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 26, 46, 256)  0           ['conv2d_146[0][0]',
#                                                                   'conv2d_149[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 26, 46, 128)  295040      ['concatenate_21[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 26, 46, 128)  147584      ['conv2d_150[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 52, 92, 128)  0          ['conv2d_151[0][0]']
#  )
#
#  conv2d_152 (Conv2D)            (None, 52, 92, 64)   73792       ['up_sampling2d_22[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 92, 128)  0           ['conv2d_144[0][0]',
#                                                                   'conv2d_152[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 52, 92, 64)   73792       ['concatenate_22[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 52, 92, 64)   36928       ['conv2d_153[0][0]']
#
#  up_sampling2d_23 (UpSampling2D  (None, 104, 184, 64  0          ['conv2d_154[0][0]']
#  )                              )
#
#  conv2d_155 (Conv2D)            (None, 104, 184, 32  18464       ['up_sampling2d_23[0][0]']
#                                 )
#
#  concatenate_23 (Concatenate)   (None, 104, 184, 64  0           ['conv2d_142[0][0]',
#                                 )                                 'conv2d_155[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 104, 184, 32  18464       ['concatenate_23[0][0]']
#                                 )
#
#  conv2d_157 (Conv2D)            (None, 104, 184, 32  9248        ['conv2d_156[0][0]']
#                                 )
#
#  conv2d_158 (Conv2D)            (None, 104, 184, 1)  33          ['conv2d_157[0][0]']
#
# ==================================================================================================
# Total params: 2,140,641
# Trainable params: 2,140,641
# Non-trainable params: 0
# __________________________________________________________________________________________________
